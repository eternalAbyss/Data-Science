# %% [markdown]
# # Machine Learning Foundations

# %%
# Importing the modules
import numpy as np
import pandas as pd

# %%
data = pd.read_excel(r"../data/Starbucks Dataset.xlsx")

# %% [markdown]
# `data.head()` : Gives you the first 5 observation

# %%
data.head()
# Out:
#    Amount of Prepaid card  Age  Days per month at starbucks  \
# 0                       5   25                            4
# 1                      25   30                           12
# 2                      10   27                           10
# 3                       5   42                            8
# 4                      15   29                           11
#
#    Cups of Coffee per day  Income
# 0                       1      20
# 1                       5      35
# 2                       4      30
# 3                       5      30
# 4                       8      25

# %% [markdown]
# `data.tail()` : Gives you the last 5 observation

# %%
data.tail()
# Out:
#     Amount of Prepaid card  Age  Days per month at starbucks  \
# 20                      25   27                           12
# 21                      25   29                           14
# 22                      50   34                           10
# 23                      15   30                            6
# 24                      20   22                            8
#
#     Cups of Coffee per day  Income
# 20                       3      35
# 21                       6      45
# 22                       3      55
# 23                       5      30
# 24                       8      20

# %%
data.describe()
# Out:
#        Amount of Prepaid card        Age  Days per month at starbucks  \
# count               25.000000  25.000000                    25.000000
# mean                31.800000  32.720000                    10.760000
# std                 40.745143   8.403967                     4.013311
# min                  5.000000  20.000000                     3.000000
# 25%                 10.000000  27.000000                     8.000000
# 50%                 20.000000  30.000000                    10.000000
# 75%                 35.000000  38.000000                    12.000000
# max                200.000000  51.000000                    19.000000
#
#        Cups of Coffee per day     Income
# count               25.000000  25.000000
# mean                 4.600000  36.200000
# std                  2.345208  13.865425
# min                  1.000000  20.000000
# 25%                  3.000000  30.000000
# 50%                  5.000000  35.000000
# 75%                  5.000000  40.000000
# max                 10.000000  80.000000
